# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1= pd.read_csv("deaths.csv")
data2= pd.read_csv("immigrants_emigrants_by_sex.csv")
data1
# Out:
#       Year  District.Code        District.Name  Neighborhood.Code  \
# 0     2017              1         Ciutat Vella                  1
# 1     2017              1         Ciutat Vella                  2
# 2     2017              1         Ciutat Vella                  3
# 3     2017              1         Ciutat Vella                  4
# 4     2017              2             Eixample                  5
# 5     2017              2             Eixample                  6
# 6     2017              2             Eixample                  7
# 7     2017              2             Eixample                  8
# 8     2017              2             Eixample                  9
# 9     2017              2             Eixample                 10
# 10    2017              3       Sants-Montjuïc                 11
# 11    2017              3       Sants-Montjuïc                 12
# 12    2017              3       Sants-Montjuïc                 13
# ...

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10= 0

for i in range(1533):
    if(data1.loc[i]['District.Name']=="Ciutat Vella"):
                 num1+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Eixample"):
                 num2+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sants-Montjuïc"):
                 num3+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Les Corts"):
                 num4+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sarrià-Sant Gervasi"):
                 num5+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Gràcia"):
                 num6+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Horta-Guinardó"):
                 num7+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Nou Barris"):
                 num8+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sant Andreu"):
                 num9+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sant Martí"):
                 num10+= data1.loc[i]['Number']
arr= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]

# %%
place=['Ciutat Vella','Eixample','Sants-Montjuïc','Les Corts','Sarrià-Sant Gervasi','Gràcia','Horta-Guinardó','Nou Barris','Sant Andreu','Sant Martí']
arr
# Out:
# [813, 2738, 1760, 765, 1362, 1176, 1806, 1749, 1326, 2069]

# %%
plt.barh(place,arr)
plt.title("Deaths by place in 2017")
plt.xlabel("Number")
plt.ylabel("Place")
arr
# Out:
# [813, 2738, 1760, 765, 1362, 1176, 1806, 1749, 1326, 2069]

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10= 0

for i in range(1534,3066):
    if(data1.loc[i]['District.Name']=="Ciutat Vella"):
                 num1+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Eixample"):
                 num2+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sants-Montjuïc"):
                 num3+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Les Corts"):
                 num4+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sarrià-Sant Gervasi"):
                 num5+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Gràcia"):
                 num6+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Horta-Guinardó"):
                 num7+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Nou Barris"):
                 num8+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sant Andreu"):
                 num9+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sant Martí"):
                 num10+= data1.loc[i]['Number']
arr1= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]

# %%
plt.barh(place,arr1)
plt.title("Deaths by place in 2016")
plt.ylabel('Place')
plt.xlabel('Number')
arr1
# Out:
# [792, 2660, 1603, 762, 1393, 1205, 1841, 1622, 1288, 2017]

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10= 0

for i in range(3067,4599):
    if(data1.loc[i]['District.Name']=="Ciutat Vella"):
                 num1+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Eixample"):
                 num2+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sants-Montjuïc"):
                 num3+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Les Corts"):
                 num4+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sarrià-Sant Gervasi"):
                 num5+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Gràcia"):
                 num6+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Horta-Guinardó"):
                 num7+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Nou Barris"):
                 num8+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sant Andreu"):
                 num9+= data1.loc[i]['Number']
    elif(data1.loc[i]['District.Name']=="Sant Martí"):
                 num10+= data1.loc[i]['Number']
arr2= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]

# %%
plt.barh(place,arr2)
plt.title("Deaths by place in 2015")
plt.ylabel('Place')
plt.xlabel('Number')
arr2
# Out:
# [829, 2730, 1690, 769, 1401, 1229, 1798, 1679, 1290, 2062]

# %%
plt.plot(arr2,place,label="2015")
plt.plot(arr1,place,label="2016")
plt.plot(arr,place,label="2017")
plt.legend(loc="upper right",frameon=False)
plt.title("Death pattern in 2015,2016,2017")
plt.xlabel("Number of deaths")
plt.ylabel("Place")
# Out:
# Text(0,0.5,'Place')

# %%
data2
# Out:
#      Year  District Code        District Name  Neighborhood Code  \
# 0    2017              1         Ciutat Vella                  1
# 1    2017              1         Ciutat Vella                  2
# 2    2017              1         Ciutat Vella                  3
# 3    2017              1         Ciutat Vella                  4
# 4    2017              2             Eixample                  5
# 5    2017              2             Eixample                  6
# 6    2017              2             Eixample                  7
# 7    2017              2             Eixample                  8
# 8    2017              2             Eixample                  9
# 9    2017              2             Eixample                 10
# 10   2017              3       Sants-Montjuïc                 11
# 11   2017              3       Sants-Montjuïc                 12
# 12   2017              3       Sants-Montjuïc                 13
# ...

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10= 0

for i in range(146):
    if(data2.loc[i]['District Name']=="Ciutat Vella"):
                 num1+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Eixample"):
                 num2+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sants-Montjuïc"):
                 num3+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Les Corts"):
                 num4+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sarrià-Sant Gervasi"):
                 num5+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Gràcia"):
                 num6+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Horta-Guinardó"):
                 num7+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Nou Barris"):
                 num8+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sant Andreu"):
                 num9+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sant Martí"):
                 num10+= data2.loc[i]['Emigrants']
arr3= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]

# %%
plt.barh(place,arr3)
plt.title("Emigrants in the year 2017")
plt.xlabel("Number of Emigrants")
plt.ylabel("Place")
# Out:
# Text(0,0.5,'Place')

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10= 0

for i in range(147,292):
    if(data2.loc[i]['District Name']=="Ciutat Vella"):
                 num1+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Eixample"):
                 num2+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sants-Montjuïc"):
                 num3+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Les Corts"):
                 num4+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sarrià-Sant Gervasi"):
                 num5+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Gràcia"):
                 num6+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Horta-Guinardó"):
                 num7+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Nou Barris"):
                 num8+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sant Andreu"):
                 num9+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sant Martí"):
                 num10+= data2.loc[i]['Emigrants']
arr4= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]

# %%
plt.barh(place,arr4)
plt.title("Emigrants in the year 2016")
plt.xlabel("Number of Emigrants")
plt.ylabel("Place")
# Out:
# Text(0,0.5,'Place')

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10= 0

for i in range(293,438):
    if(data2.loc[i]['District Name']=="Ciutat Vella"):
                 num1+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Eixample"):
                 num2+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sants-Montjuïc"):
                 num3+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Les Corts"):
                 num4+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sarrià-Sant Gervasi"):
                 num5+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Gràcia"):
                 num6+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Horta-Guinardó"):
                 num7+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Nou Barris"):
                 num8+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sant Andreu"):
                 num9+= data2.loc[i]['Emigrants']
    elif(data2.loc[i]['District Name']=="Sant Martí"):
                 num10+= data2.loc[i]['Emigrants']
arr5= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]

# %%
plt.barh(place,arr5)
plt.title("Emigrants in the year 2015")
plt.xlabel("Number of Emigrants")
plt.ylabel("Place")
# Out:
# Text(0,0.5,'Place')

# %%
plt.plot(arr5,place,label="2015",color="red")
plt.plot(arr4,place,label="2016",color="blue")
plt.plot(arr3,place,label="2017",color="green")
plt.legend(loc= "upper right",frameon=False)
plt.title("Emigration pattern in year 2015,2016,2017")
plt.xlabel("Number of Emigrants")
plt.ylabel("Place")
# Out:
# Text(0,0.5,'Place')

# %%
plt.plot(arr2,place,label="2015")
plt.plot(arr1,place,label="2016")
plt.plot(arr,place,label="2017")
plt.legend(loc="upper right",frameon=False)
plt.title("Death pattern in 2015,2016,2017")
plt.xlabel("Number of deaths")
plt.ylabel("Place")
# Out:
# Text(0,0.5,'Place')
