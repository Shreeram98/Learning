# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1= pd.read_csv("immigrants_emigrants_by_age.csv")
data2= pd.read_csv("unemployment.csv")
data1
# Out:
#       Year  District Code        District Name  Neighborhood Code  \
# 0     2017              1         Ciutat Vella                  1
# 1     2017              1         Ciutat Vella                  2
# 2     2017              1         Ciutat Vella                  3
# 3     2017              1         Ciutat Vella                  4
# 4     2017              2             Eixample                  5
# 5     2017              2             Eixample                  6
# 6     2017              2             Eixample                  7
# 7     2017              2             Eixample                  8
# 8     2017              2             Eixample                  9
# 9     2017              2             Eixample                 10
# 10    2017              3       Sants-Montjuïc                 11
# 11    2017              3       Sants-Montjuïc                 12
# 12    2017              3       Sants-Montjuïc                 13
# ...

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10 =0
for i in range(1,1554):
    if(data1.loc[i]["District Code"]== 1):
                 num1+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==2):
                 num2+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==3):
                 num3+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==4):
                 num4+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==5):
                 num5+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==6):
                 num6+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==7):
                 num7+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==8):
                 num8+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==9):
                 num9+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==10):
                 num10+= data1.loc[i]['Emigrants']
em_arr1= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]
em_arr1
# Out:
# [4521, 8883, 7136, 2659, 4037, 3807, 4860, 5061, 4214, 7362]

# %%
place=['Ciutat Vella','Eixample','Sants-Montjuïc','Les Corts','Sarrià-Sant Gervasi','Gràcia','Horta-Guinardó','Nou Barris','Sant Andreu','Sant Martí']
plt.barh(place,em_arr1)
plt.title("Emigrants in 2017")
plt.xlabel("Number of Emigrants")
plt.ylabel("From")
# Out:
# Text(0,0.5,'From')

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10 =0
for i in range(1555,3108):
    if(data1.loc[i]["District Code"]== 1):
                 num1+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==2):
                 num2+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==3):
                 num3+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==4):
                 num4+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==5):
                 num5+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==6):
                 num6+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==7):
                 num7+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==8):
                 num8+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==9):
                 num9+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==10):
                 num10+= data1.loc[i]['Emigrants']
em_arr2= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]
em_arr2
# Out:
# [4393, 8280, 6925, 2486, 4094, 3535, 4418, 4648, 4071, 7302]

# %%
place=['Ciutat Vella','Eixample','Sants-Montjuïc','Les Corts','Sarrià-Sant Gervasi','Gràcia','Horta-Guinardó','Nou Barris','Sant Andreu','Sant Martí']
plt.barh(place,em_arr2)
plt.title("Emigrants in 2016")
plt.xlabel("Number of Emigrants")
plt.ylabel("From")
# Out:
# Text(0,0.5,'From')

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10 =0
for i in range(3109,4662):
    if(data1.loc[i]["District Code"]== 1):
                 num1+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==2):
                 num2+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==3):
                 num3+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==4):
                 num4+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==5):
                 num5+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==6):
                 num6+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==7):
                 num7+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==8):
                 num8+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==9):
                 num9+= data1.loc[i]['Emigrants']
    elif(data1.loc[i]["District Code"]==10):
                 num10+= data1.loc[i]['Emigrants']
em_arr3= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]
em_arr3
# Out:
# [4920, 8899, 7758, 2666, 4248, 3667, 4658, 5093, 4278, 7806]

# %%
plt.barh(place,em_arr3)
plt.title("Emigrants in 2015")
plt.xlabel("Number of Emigrants")
plt.ylabel("From")
# Out:
# Text(0,0.5,'From')

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10 =0
for i in range(1,3552):
    if(data2.loc[i]["District Code"]== 1):
                 num1+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==2):
                 num2+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==3):
                 num3+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==4):
                 num4+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==5):
                 num5+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==6):
                 num6+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==7):
                 num7+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==8):
                 num8+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==9):
                 num9+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==10):
                 num10+= data2.loc[i]['Number']
un_arr1= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]
un_arr1
# Out:
# [98993, 156307, 137051, 45267, 53710, 74763, 122615, 151558, 113962, 181531]

# %%
plt.barh(place,un_arr1)
plt.title("Unemployment in 2017")
plt.xlabel("Number of Unemployees")
plt.ylabel("In")
# Out:
# Text(0,0.5,'In')

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10 =0
for i in range(3553,7104):
    if(data2.loc[i]["District Code"]== 1):
                 num1+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==2):
                 num2+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==3):
                 num3+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==4):
                 num4+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==5):
                 num5+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==6):
                 num6+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==7):
                 num7+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==8):
                 num8+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==9):
                 num9+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==10):
                 num10+= data2.loc[i]['Number']
un_arr2= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]
un_arr2
# Out:
# [105883, 169554, 150737, 50409, 58837, 81524, 134106, 165362, 126461, 196603]

# %%
plt.barh(place,un_arr2)
plt.title("Unemployment in 2016")
plt.xlabel("Number of Unemployees")
plt.ylabel("In")
# Out:
# Text(0,0.5,'In')

# %%
num1= 0
num2= 0
num3= 0
num4= 0
num5= 0
num6= 0
num7= 0
num8= 0
num9= 0
num10 =0
for i in range(7105,10656):
    if(data2.loc[i]["District Code"]== 1):
                 num1+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==2):
                 num2+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==3):
                 num3+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==4):
                 num4+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==5):
                 num5+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==6):
                 num6+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==7):
                 num7+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==8):
                 num8+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==9):
                 num9+= data2.loc[i]['Number']
    elif(data2.loc[i]["District Code"]==10):
                 num10+= data2.loc[i]['Number']
un_arr3= [num1,num2,num3,num4,num5,num6,num7,num8,num9,num10]
un_arr3
# Out:
# [116443, 190472, 169975, 56920, 65740, 91576, 150144, 185439, 143754, 220456]

# %%
plt.barh(place,un_arr3)
plt.title("Unemployment in 2015")
plt.xlabel("Number of Unemployees")
plt.ylabel("In")
# Out:
# Text(0,0.5,'In')
